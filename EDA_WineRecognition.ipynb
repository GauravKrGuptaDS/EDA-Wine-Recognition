# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravKrGuptaDS/EDA-Wine-Recognition/blob/main/EDA_WineRecognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Important Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the data
df = pd.read_csv('/content/Wine.csv')
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
# Getting the shape of the data
print('Shape : ', df.shape)
# Out:
# Shape :  (178, 14)

# %%
# getting an idea about the duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# np.int64(0) means there are no duplicates in the data

# %%
# Getting an idea about the NULL values
df.isnull().sum().any()
# Out:
# np.False_

# %%
# np.False_ means there are no NULL value in the data

# %%
# getting an idea about the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         178 non-null    int64
#  1   Alcohol                       178 non-null    float64
#  2   Malic acid                    178 non-null    float64
#  3   Ash                           178 non-null    float64
#  4   Alcalinity of ash             178 non-null    float64
#  5   Magnesium                     178 non-null    int64
#  6   Total phenols                 178 non-null    float64
#  7   Flavanoids                    178 non-null    float64
#  8   Nonflavanoid phenols          178 non-null    float64
#  9   Proanthocyanins               178 non-null    float64
#  10  Color intensity               178 non-null    float64
#  11  Hue                           178 non-null    float64
# ...

# %%
df['Class'].unique()
# Out:
# array([1, 2, 3])

# %%
df['Class'].value_counts()
# Out:
# Class
# 2    71
# 1    59
# 3    48
# Name: count, dtype: int64

# %%
df_one = df[df['Class'] == 1]
df_one.shape
# Out:
# (59, 14)

# %%
# Correlation Analysis
#df_one = df[df['Class'] == 1]

cm = df.corr(numeric_only = True)
plt.figure(figsize = (20, 5))
sns.heatmap(cm, annot = True)
plt.show()

# %%
'''
Conclusions ->
1. Class and Alcalinity of ash has moderate positive relationship.
2. Class and Total phenols has moderate negative relationship.
3. Class and Flavanoids has negative relationship.
4. Class and Nonflavanoid phenols has moderate positive relationship.
5. Class and Proanthocyanins has moderate negative relationship.
6. Class and Hue has moderate negative relationship.
7. Class and 'OD280/OD315 of diluted wines' has negative relationship.
8. Class and Proline has moderate negative relationship.
'''
# Out:
# "\nConclusions ->\n1. Class and Alcalinity of ash has moderate positive relationship.\n2. Class and Total phenols has moderate negative relationship.\n3. Class and Flavanoids has negative relationship.\n4. Class and Nonflavanoid phenols has moderate positive relationship.\n5. Class and Proanthocyanins has moderate negative relationship.\n6. Class and Hue has moderate negative relationship.\n7. Class and 'OD280/OD315 of diluted wines' has negative relationship.\n8. Class and Proline has moderate negative relationship. \n"

# %%
#Analytical Analysis
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
'''
Conclusions ->
 1. For Alcohol, mean is almost same as median, which tells that its distribution is symmetric.
 2. For Malic acid, mean is greater than median, which tells that its distribution is right skewed.
 3. For Ash, mean is almost same as median, which tells that its distribution is symmetric.
 4. For Alcalinity of ash, mean is almost same as median, which tells that its distribution is symmetric.
 5. For Magnesium, mean is slightly greater than median, which tells that its distribution is slightly right skewed.
 6. For Total phenols, mean is slightly lesser than median, which tells that its distribution is slightly left skewed.
 7. For Flavanoids, mean is slightly lesser than median, which tells that its distribution is slightly left skewed.
 8. For Nonflavanoid phenols, mean is greater than median, which tells that its distribution is right skewed.
 9. For Proanthocyanins, mean is greater than median, which tells that its distribution is right skewed.
10. For Color intensity, mean is greater than median, which tells that its distribution is right skewed.
11. For Hue, mean is slightly lesser than median, which tells that its distribution is slightly left skewed.
12. For OD280/OD315 of diluted wines, mean is lesser than median, which tells that its distribution is left skewed.
13. For Proline, mean is greater than median, which tells that its distribution is right skewed.
'''
# Out:
# '\nConclusions ->\n 1. For Alcohol, mean is almost same as median, which tells that its distribution is symmetric.\n 2. For Malic acid, mean is greater than median, which tells that its distribution is right skewed.\n 3. For Ash, mean is almost same as median, which tells that its distribution is symmetric.\n 4. For Alcalinity of ash, mean is almost same as median, which tells that its distribution is symmetric.\n 5. For Magnesium, mean is slightly greater than median, which tells that its distribution is slightly right skewed.\n 6. For Total phenols, mean is slightly lesser than median, which tells that its distribution is slightly left skewed.\n 7. For Flavanoids, mean is slightly lesser than median, which tells that its distribution is slightly left skewed.\n 8. For Nonflavanoid phenols, mean is greater than median, which tells that its distribution is right skewed.\n 9. For Proanthocyanins, mean is greater than median, which tells that its distribution is right skewed.\n10. For C
# ...

# %%
# Distribution plot
plt.figure(figsize = (15, 12))

plt.subplot(331)
sns.distplot(df['Alcohol'])

plt.subplot(332)
sns.distplot(df['Malic acid'])

plt.subplot(333)
sns.distplot(df['Ash'])

plt.subplot(334)
sns.distplot(df['Alcalinity of ash'])

plt.subplot(335)
sns.distplot(df['Magnesium'])

plt.subplot(336)
sns.distplot(df['Total phenols'])

plt.subplot(337)
sns.distplot(df['Flavanoids'])

plt.subplot(338)
sns.distplot(df['Nonflavanoid phenols'])

plt.subplot(339)
sns.distplot(df['Proanthocyanins'])

plt.show()

# %%
# Distribution plot
plt.figure(figsize = (12, 8))

plt.subplot(221)
sns.distplot(df['Color intensity'])

plt.subplot(222)
sns.distplot(df['Hue'])

plt.subplot(223)
sns.distplot(df['OD280/OD315 of diluted wines'])

plt.subplot(224)
sns.distplot(df['Proline'])

plt.show()

# %%
# Box plot
plt.figure(figsize = (15, 12))

plt.subplot(241)
df.boxplot('Alcalinity of ash')

plt.subplot(242)
df.boxplot('Total phenols')

plt.subplot(243)
df.boxplot('Flavanoids')

plt.subplot(244)
df.boxplot('Nonflavanoid phenols')

plt.subplot(245)
df.boxplot('Proanthocyanins')

plt.subplot(246)
df.boxplot('Hue')

plt.subplot(247)
df.boxplot('OD280/OD315 of diluted wines')

plt.subplot(248)
df.boxplot('Proline')

plt.show()

# %%
'''
Conclusions ->
1. For Alcalinity of ash, there are 2 outliers on higher side and one on lower side.
2. For Proanthocyanins, there are 2 outliers on higher side.
3. For Hue, there are one outlier on higher side.
4. For Total phenols, Flavanoids, Nonflavanoid phenols, 'OD280/OD315 of diluted wines' and Proline, ther are no outliers.
'''
# Out:
# "\nConclusions ->\n1. For Alcalinity of ash, there are 2 outliers on higher side and one on lower side.\n2. For Proanthocyanins, there are 2 outliers on higher side.\n3. For Hue, there are one outlier on higher side.\n4. For Total phenols, Flavanoids, Nonflavanoid phenols, 'OD280/OD315 of diluted wines' and Proline, ther are no outliers.\n"

# %%
# Relationship plot between Alcalinity of ash and Total phenols w.r.t. Class
plt.figure(figsize = (15, 5))
sns.relplot(x = 'Alcalinity of ash', y = 'Total phenols', hue = 'Class', data = df)
plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Class 1, for Total phenols, is found between the range of 2.1 and 3.5
2. The maximum distribution of Class 1, for Alcalinity of ash, is found between the range of 11 and 21
3. The maximum distribution of Class 2, for Total phenols, is found between the range of 1.1 and 3
4. The maximum distribution of Class 2, for Alcalinity of ash, is found between the range of 15 and 26
5. The maximum distribution of Class 3, for Total phenols, is found between the range of 1.1 and 2
6. The maximum distribution of Class 3, for Alcalinity of ash, is found between the range of 17.5 and 25
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Class 1, for Total phenols, is found between the range of 2.1 and 3.5\n2. The maximum distribution of Class 1, for Alcalinity of ash, is found between the range of 11 and 21\n3. The maximum distribution of Class 2, for Total phenols, is found between the range of 1.1 and 3\n4. The maximum distribution of Class 2, for Alcalinity of ash, is found between the range of 15 and 26\n5. The maximum distribution of Class 3, for Total phenols, is found between the range of 1.1 and 2\n6. The maximum distribution of Class 3, for Alcalinity of ash, is found between the range of 17.5 and 25\n'

# %%
# Relationship plot between Flavanoids and Nonflavanoid phenols w.r.t. Class
plt.figure(figsize = (15, 5))
sns.relplot(x = 'Flavanoids', y = 'Nonflavanoid phenols', hue = 'Class', data = df)
plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Class 1, for Flavanoids, is found between the range of 2.1 and 4
2. The maximum distribution of Class 1, for Nonflavanoid phenols, is found between the range of 0.1 and 0.45
3. The maximum distribution of Class 2, for Flavanoids, is found between the range of 1.2 and 3.2
4. The maximum distribution of Class 2, for Nonflavanoid phenols, is found between the range of 0.2 and 0.55
5. The maximum distribution of Class 3, for Flavanoids, is found between the range of 0.2 and 1.5
6. The maximum distribution of Class 3, for Nonflavanoid phenols, is found between the range of 0.2 and 0.64
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Class 1, for Flavanoids, is found between the range of 2.1 and 4\n2. The maximum distribution of Class 1, for Nonflavanoid phenols, is found between the range of 0.1 and 0.45\n3. The maximum distribution of Class 2, for Flavanoids, is found between the range of 1.2 and 3.2\n4. The maximum distribution of Class 2, for Nonflavanoid phenols, is found between the range of 0.2 and 0.55\n5. The maximum distribution of Class 3, for Flavanoids, is found between the range of 0.2 and 1.5\n6. The maximum distribution of Class 3, for Nonflavanoid phenols, is found between the range of 0.2 and 0.64\n'

# %%
# Relationship plot between Proanthocyanins and Hue w.r.t. Class
plt.figure(figsize = (15, 5))
sns.relplot(x = 'Proanthocyanins', y = 'Hue', hue = 'Class', data = df)
plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Class 1, for Proanthocyanins, is found between the range of 1.2 and 2.5
2. The maximum distribution of Class 1, for Hue, is found between the range of 0.8 and 1.3
3. The maximum distribution of Class 2, for Proanthocyanins, is found between the range of 1 and 2.1
4. The maximum distribution of Class 2, for Hue, is found between the range of 0.7 and 1.4
5. The maximum distribution of Class 3, for Proanthocyanins, is found between the range of 0.5 and 1.6
6. The maximum distribution of Class 3, for Hue, is found between the range of 0.3 and 1
'''
# Out:
# '\nConclusions ->\n1. The maximum distribution of Class 1, for Proanthocyanins, is found between the range of 1.2 and 2.5\n2. The maximum distribution of Class 1, for Hue, is found between the range of 0.8 and 1.3\n3. The maximum distribution of Class 2, for Proanthocyanins, is found between the range of 1 and 2.1\n4. The maximum distribution of Class 2, for Hue, is found between the range of 0.7 and 1.4\n5. The maximum distribution of Class 3, for Proanthocyanins, is found between the range of 0.5 and 1.6\n6. The maximum distribution of Class 3, for Hue, is found between the range of 0.3 and 1\n'

# %%
# Relationship plot between 'OD280/OD315 of diluted wines' and Proline w.r.t. Class
plt.figure(figsize = (15, 5))
sns.relplot(x = 'OD280/OD315 of diluted wines', y = 'Proline', hue = 'Class', data = df)
plt.show()

# %%
'''
Conclusions ->
1. The maximum distribution of Class 1, for 'OD280/OD315 of diluted wines', is found between the range of 2.5 and 3.7
2. The maximum distribution of Class 1, for Proline, is found between the range of 750 and 1400
3. The maximum distribution of Class 2, for 'OD280/OD315 of diluted wines', is found between the range of 2 and 3.5
4. The maximum distribution of Class 2, for Proline, is found between the range of 275 and 750
5. The maximum distribution of Class 3, for 'OD280/OD315 of diluted wines', is found between the range of 1.25 and 2.2
6. The maximum distribution of Class 3, for Proline, is found between the range of 450 and 900
'''
